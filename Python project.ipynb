# %%
# Out:
#   Cell In[3], line 1
#     def reverse_names(name_input)
#                                  ^
# SyntaxError: expected ':'

# %%
# Function to reverse the names
def reverse_names(name_string):  # Added colon here

# %%
import numpy as np

# %%
type(df.values) stores.csv
# Out:
#   Cell In[5], line 1
#     type(df.values) stores.csv
#                     ^
# SyntaxError: invalid syntax
